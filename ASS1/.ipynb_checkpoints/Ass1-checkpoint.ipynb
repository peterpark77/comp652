# %%
import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import linear_model
from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
import sklearn
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.linear_model import Lasso
import matplotlib.patches as mpatches

import math
from sklearn.model_selection import KFold
from scipy.stats import norm
from sklearn.preprocessing import normalize
from sklearn.preprocessing import scale
from mpl_toolkits.mplot3d import Axes3D


X = np.loadtxt("hw1-q1x.csv")
Y = np.loadtxt("hw1-q1y.csv")

# %%
Y.mean()
# Out:
# 25.801389809800003

# %%
data = np.column_stack((X,Y))

# %%
X_1_added = np.insert(X, 0, 1, axis=1)

# %%
### 1(a) data processing

X_data = np.insert(X,0,1, axis=1)

X_data_normalize = scale(X)

# %%
#visualize daa

plt.plot(scale(X))

#bigger fluctuation original data
plt.plot(X)
plt.show()

# %%
#shape of the data
print(X.shape)
print(Y.shape)
# Out:
# (100, 2)
# (100,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
# 3D plot
np.random.seed(19680801)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y, c='r', marker='o')

ax.set_xlabel('X1 Label')
ax.set_ylabel('X2 Label')
ax.set_zlabel('Y Label')

plt.show()

# %%
#X_1 to Y

plt.scatter(X[:,0], Y)
plt.show()

# %% [markdown]
# 1

# %% [markdown]
# 1(b)

# %%
reg_parameter = [0, 0.1] + [10**i for i in range(6)]

#scale the input

train_set, test_set, y_train, y_test = train_test_split(X_1_added, Y, test_size=0.2, random_state=423)

X_train = pd.DataFrame(train_set)
X_test = pd.DataFrame(test_set)

#store coefficients / intercept

rmse_add = []
test_rmse_add = []
weight_vectors = []
intercept_vectors = []
l2_norm = []

for reg in reg_parameter:
    lin_reg = Ridge(alpha=reg, fit_intercept=False,random_state = 42)
    lin_reg.fit(X_train, y_train)

    y_predict = lin_reg.predict(X_train)
    lin_mse = mean_squared_error(y_train, y_predict)
    lin_rmse = np.sqrt(lin_mse)
    rmse_add.append(lin_rmse)
    weight_vectors.append(lin_reg.coef_)
    intercept_vectors.append(lin_reg.intercept_)
    l2_norm.append(np.linalg.norm(lin_reg.coef_))

    test_y_predict = lin_reg.predict(X_test)
    lin_mse_test = mean_squared_error(y_test, test_y_predict)
    lin_rmse_test = np.sqrt(lin_mse_test)
    test_rmse_add.append(lin_rmse_test)
print("The training RMSE is the following:")
print(rmse_add)
print("The test RMSE is the following:")
print(test_rmse_add)
print("The L2 norm is the following:")
print(l2_norm)

plt.plot(reg_parameter, rmse_add, 'b', label='Training data')
plt.plot(reg_parameter, test_rmse_add, 'g', label='Test data')
plt.xlabel('Regularization parameter')
plt.ylabel('Linear Regression RMSE')
plt.xscale('log')
plt.legend()
plt.show()

plt.plot(reg_parameter, l2_norm)
plt.xlabel('Regularization parameter')
plt.ylabel('L2 Norm of Weight Vectors')
plt.xscale('log')
plt.show()

plt.plot(reg_parameter, [i[1] for i in weight_vectors], 'r', label = 'first weight')
plt.plot(reg_parameter, [i[2] for i in weight_vectors], label = 'second weight')
plt.xlabel('Regularization parameter')
plt.ylabel('weight value')
plt.xscale('log')
plt.legend()
plt.show()
# Out:
# The training RMSE is the following:
# [14.261187279589498, 14.261206315825978, 14.262950535153244, 14.354995267063007, 15.226854966384233, 22.160077759494779, 35.16590317891275, 39.065546837827242]
# The test RMSE is the following:
# [17.564328560179671, 17.56841910436173, 17.605244662515659, 17.942078801274352, 19.398754822420496, 27.564568813087675, 42.151286328845778, 46.384477551566405]
# The L2 norm is the following:
# [13.690767116063356, 13.658933921063058, 13.387111590906382, 11.634183532108157, 8.7666509872829419, 4.9125898240384567, 1.1014078012091091, 0.12780584513808482]

# %%
print(test_rmse_add.index(min(test_rmse_add)), " is the best lambda value for part 1(b)")
# Out:
# 0  is the best lambda value for part 1(b)

# %% [markdown]
# Following is just for visualization purposes:

# %%
##JUST FOR VISUALIZATION PURPOSES###
Y_fit = []
t = np.arange(-2,8, 0.01)
for j in range(len(weight_vectors)):
    Y_sub = []
    for i in t:
        Y_sub.append(weight_vectors[j][1]*i + weight_vectors[j][2]*i + weight_vectors[j][0])
    Y_fit.append(Y_sub)
plt.scatter(X[:,0],Y, c= 'r')
plt.plot(t,Y_fit[1])
plt.show()
plt.scatter(X[:,1],Y, c= 'g')
plt.plot(t,Y_fit[1])
plt.show()

# %%
reg_parameter = [ 0, 0.1] + [10**i for i in range(6)]
print(reg_parameter)

#scale the input

train_set, test_set, y_train, y_test = train_test_split(scale(X), Y, test_size=0.2, random_state=42)

X_train = pd.DataFrame(train_set)
X_test = pd.DataFrame(test_set)

#store coefficients / intercept

rmse = []
test_rmse = []
weight_vectors = []
intercept_vectors = []
l2_norm = []

for reg in reg_parameter:
    lin_reg = Ridge(alpha=reg, fit_intercept=True)
    lin_reg.fit(X_train, y_train)

    y_predict = lin_reg.predict(X_train)
    lin_mse = mean_squared_error(y_train, y_predict)
    lin_rmse = np.sqrt(lin_mse)
    rmse.append(lin_rmse)
    weight_vectors.append(lin_reg.coef_)
    intercept_vectors.append(lin_reg.intercept_)
    l2_norm.append(np.linalg.norm(lin_reg.coef_))

    test_y_predict = lin_reg.predict(X_test)
    lin_mse_test = mean_squared_error(y_test, test_y_predict)
    lin_rmse_test = np.sqrt(lin_mse_test)
    test_rmse.append(lin_rmse_test)
print(rmse)
print(test_rmse)
print(l2_norm)

plt.plot(reg_parameter, rmse, 'b', label='Training data')
plt.plot(reg_parameter, test_rmse, 'g', label='Test data')
plt.xlabel('Regularization parameter')
plt.ylabel('Linear Regression RMSE')
plt.xscale('log')
plt.legend()
plt.show()

plt.plot(reg_parameter, l2_norm)
plt.xlabel('Regularization parameter')
plt.ylabel('L2 Norm of Weight Vectors')
plt.xscale('log')
plt.show()

plt.plot(reg_parameter, [i[0] for i in weight_vectors], 'r', label = 'first weight')
plt.plot(reg_parameter, [i[1] for i in weight_vectors], label = 'second weight')
plt.xlabel('Regularization parameter')
plt.ylabel('weight value')
plt.xscale('log')
plt.legend()
plt.show()
# Out:
# [0, 0.1, 1, 10, 100, 1000, 10000, 100000]
# [15.287216333000899, 15.287250770459943, 15.290590046779414, 15.562751005356986, 21.535886953318705, 30.313149122374682, 32.099162787317027, 32.295160447149897]
# [13.636846645431705, 13.650214062994309, 13.770544791125705, 14.95356797819248, 22.109205253707042, 29.54684806527473, 30.978639461095515, 31.134872988038538]
# [27.196646572999231, 27.165639534590927, 26.889729918331007, 24.410782232228289, 12.70502525749626, 2.1930199982161787, 0.23647925201756487, 0.023834626411439994]

# %%
print(test_rmse_add.index(min(test_rmse_add)), " is the best lambda value for part 1(c) with cross validation")
# Out:
# 0  is the best lambda value for part 1(c) with cross validation

# %%
Y_fit = []
t = np.arange(-2,2, 0.01)
for j in range(len(weight_vectors)):
    Y_sub = []
    for i in t:
        Y_sub.append(weight_vectors[j][1]*i + weight_vectors[2][1]*i + intercept_vectors[j])
    Y_fit.append(Y_sub)
plt.scatter(scale(X[:,0]),Y, c= 'r')
plt.plot(t,Y_fit[0])
plt.show()
plt.scatter(scale(X[:,1]),Y, c= 'g')
plt.plot(t,Y_fit[0])
plt.show()

# %%
average_validation_scores = {}

for par in reg_parameter:
    lin_reg = Ridge(alpha=par)
    scores = cross_validate(lin_reg, X_train, y_train, scoring='neg_mean_squared_error', cv=5, return_train_score=True
)


    print('For regularization parameter: %.1f' %par)
    print('Training scores: ' ,  str(np.sqrt(-scores['train_score'])))
    print('Average training score: ',np.average(np.sqrt(-scores['train_score'])))
    print('Validation scores: ',np.sqrt(-scores['test_score']))
    print('Average validation score: ', np.average(np.sqrt(-scores['test_score'])))
    print('\n')
    average_validation_scores[par] = np.average(np.sqrt(-scores['test_score']))
# Out:
# For regularization parameter: 0.0
# Training scores:  [ 13.53563629  15.59113941  14.70803841  16.47343471  15.71364099]
# Average training score:  15.2043779614
# Validation scores:  [ 21.28192818  14.15543063  17.56118625   9.48059086  13.64658025]
# Average validation score:  15.2251432351
#
#
# For regularization parameter: 0.1
# Training scores:  [ 13.53569454  15.59119444  14.70810316  16.47347909  15.71369282]
# Average training score:  15.2044328107
# Validation scores:  [ 21.2905267   14.14509034  17.55693361   9.49091017  13.6405595 ]
# Average validation score:  15.2248040636
#
#
# For regularization parameter: 1.0
# Training scores:  [ 13.54131016  15.59650369  14.71432828  16.47776941  15.71869727]
# Average training score:  15.2097217601
# Validation scores:  [ 21.37023137  14.05834316  17.52708441   9.58617926  13.59141503]
# Average validation score:  15.226650645
#
#
# For regularization parameter: 10.0
# Training scores:  [ 13.97342616  16.00873959  15.18199425  16.81739565  16.11001425]
# Average training score:  15.6183139824
# Validation scores:  [ 22.31852874  13.7024454   17.85270779  10.68227485  13.50013578]
# Average validation score:  15.6112185105
#
#
# For regularization parameter: 100.0
# Training scores:  [ 21.08866012  23.17513052  22.27428561  23.35176537  23.1495068 ]
# Average training score:  22.6078696838
# Validation scores:  [ 29.8593239   19.30711338  26.71799322  18.4583372   18.93193781]
# Average validation score:  22.6549411011
#
#
# For regularization parameter: 1000.0
# Training scores:  [ 28.87775423  31.44282996  29.45797456  31.72551088  31.56960982]
# Average training score:  30.6147358902
# Validation scores:  [ 37.54490296  27.43982186  36.04815505  25.96041717  26.45561387]
# Average validation score:  30.6897821802
#
#
# For regularization parameter: 10000.0
# Training scores:  [ 30.26757562  32.9472364   30.69398099  33.3202331   33.12769742]
# Average training score:  32.071344706
# Validation scores:  [ 38.92707253  28.94488366  37.65419042  27.31554457  27.86478792]
# Average validation score:  32.1412958214
#
#
# For regularization parameter: 100000.0
# Training scores:  [ 30.41698235  33.10940756  30.82609636  33.4933384   33.29610169]
# Average training score:  32.228385272
# Validation scores:  [ 39.07589264  29.10731743  37.8258372   27.46180061  28.01722609]
# Average validation score:  32.2976147965

# %%
print(min(average_validation_scores, key=average_validation_scores.get), "is the best pick for lambda")
# Out:
# 0.1 is the best pick for lambda

# %% [markdown]
# 1 (e)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
variances
# Out:
# [0.1, 0.5, 1, 5]

# %%
list_dataframes = [] # store list of transformed training set dataframes, each one has a different variance
means = [-1, -0.5, 0, 0.5, 1]
variances = [0.1, 0.5, 1, 5]

for var in variances:
    df = pd.DataFrame()
    for mean in means:
        for column in np.array(train_set).T:
            
            new_col = pd.DataFrame(np.exp(-((column-mean)**2)/(2*var) ) )
            df = pd.concat([df,new_col], axis=1)
    list_dataframes.append(df)

list_test = [] # store list of transformed test set dataframes, each one has a different variance

for var in variances:
    df = pd.DataFrame()
    for mean in means:
        for column in np.array(test_set).T:
            new_col = pd.DataFrame(np.exp(-((column-mean)**2)/(2*var) ) )
            df = pd.concat([df,new_col], axis=1)
    list_test.append(df)


gauss_train_rmse = []
gauss_test_rmse = []
for train_df, test_df in zip(list_dataframes,list_test):
    new_lin_reg = LinearRegression()
    new_lin_reg.fit(train_df, y_train)

    y_predict_train = new_lin_reg.predict(train_df)
    lin_mse = mean_squared_error(y_train, y_predict_train)
    lin_rmse = np.sqrt(lin_mse)
    gauss_train_rmse.append(lin_rmse)

    y_predict_test = new_lin_reg.predict(test_df)
    lin_mse = mean_squared_error(y_test, y_predict_test)
    lin_rmse = np.sqrt(lin_mse)
    gauss_test_rmse.append(lin_rmse)


plt.plot(variances, gauss_test_rmse, label='Testing error')
plt.plot(variances, gauss_train_rmse, label='Training error')
for scalar in rmse_add:
    plt.axhline(y=scalar, linestyle='-', color='g')
for scalar in test_rmse_add:
    plt.axhline(y=scalar, linestyle='-', color='r')
plt.xlabel('Variance')
plt.ylabel('Errors')
plt.legend()
plt.show()

# %%
###(i)



def polynomial_basis(X, degree):
    t = X[:,1]
    out = []
    for j in t:
        temp = 0
        sub_out = []
        for i in range(1,degree+1):
            sub_out.append(j**i)
        out.append(sub_out)
    return out

deg = [1,2,3,5,9]
reg = [0.01, 0.1, 1, 10]

# %%
scores_array = {}




t = ['g', 'r', 'c', 'm', 'y']
for n, i in enumerate(deg):

    transform_basis_X = np.array(polynomial_basis(X_train, i))
    if (n < 1):
        plt.scatter(transform_basis_X[:,0], Y_train, label = 'scatter')

    new_lin_reg = LinearRegression()
    new_lin_reg.fit(transform_basis_X, Y_train)
    #min_x = min(transform_basis_X[:,0])
    #max_x = max(transform_basis_X[:,0])
    #q = np.linspace()
    x_plot = np.linspace(-2, 8, 100)
    plt.plot(x_plot, new_lin_reg.predict(polynomial_basis(np.array([(i,j) for i,j in zip(x_plot,x_plot)]), i)), t[n], label='deg :' +str(i))
    scores = cross_validate(new_lin_reg, transform_basis_X, Y_train, scoring='neg_mean_squared_error', cv=5, return_train_score=True)
    scores_array[i] =  np.average(np.sqrt(-scores['test_score']))
plt.legend()
plt.show()

# %%
print(scores_array)
# Out:
# {1: 16.013335562313266, 2: 7.7294003758067005, 3: 7.9612096674856101, 5: 8.3167530749028611, 9: 9.5745730422808268}

# %%
print(min(scores_array, key=scores_array.get), "is the best pick for degree")
# Out:
# 2 is the best pick for degree

# %%
import warnings
warnings.filterwarnings('ignore')
scores_array = {}
t = ['g', 'r', 'c', 'm', 'y']
for n, i in enumerate(reg):
    transform_basis_X = np.array(polynomial_basis(X_train, 9))
    new_lin_reg = Ridge(alpha=i)
    new_lin_reg.fit(transform_basis_X, Y_train)
    #min_x = min(transform_basis_X[:,0])
    #max_x = max(transform_basis_X[:,0])
    #q = np.linspace()
    if (n < 1):
        plt.scatter(transform_basis_X[:,0], Y_train, label = 'scatter')

    x_plot = np.linspace(-2, 8, 100)
    plt.plot(x_plot, new_lin_reg.predict(polynomial_basis(np.array([(i,j) for i,j in zip(x_plot,x_plot)]), 9)), label='reg :' +str(i))
    scores = cross_validate(new_lin_reg, transform_basis_X, Y_train, scoring='neg_mean_squared_error', cv=5, return_train_score=True)
    scores_array[i] =  np.average(np.sqrt(-scores['test_score']))
plt.legend()
plt.show()

# %%
print(scores_array)
# Out:
# {0.01: 9.5731085362228292, 0.1: 9.5606091354071658, 1: 9.4768306398513733, 10: 9.3003630220285274}

# %%
print(min(scores_array, key=scores_array.get), "is the best pick for lambda")
# Out:
# 10 is the best pick for lambda

# %%
import warnings
warnings.filterwarnings('ignore')
scores_array = {}
t = ['g', 'r', 'c', 'm', 'y']


for n, i in enumerate(reg):
    transform_basis_X = np.array(polynomial_basis(X_train, 9))
    new_lin_reg = Lasso(alpha=i)
    new_lin_reg.fit(transform_basis_X, Y_train)
    #min_x = min(transform_basis_X[:,0])
    #max_x = max(transform_basis_X[:,0])
    #q = np.linspace()
    if (n < 1):
        plt.scatter(transform_basis_X[:,0], Y_train, label = 'scatter')

    x_plot = np.linspace(-2, 8, 100)
    plt.plot(x_plot, new_lin_reg.predict(polynomial_basis(np.array([(i,j) for i,j in zip(x_plot,x_plot)]), 9)), label='reg :' +str(i))
    scores = cross_validate(new_lin_reg, transform_basis_X, Y_train, scoring='neg_mean_squared_error', cv=5, return_train_score=True)
    scores_array[i] =  np.average(np.sqrt(-scores['test_score']))
plt.legend()
plt.show()

# %%
print(scores_array)
# Out:
# {0.01: 8.3251332337821147, 0.1: 8.3206567277906025, 1: 8.2625596461172375, 10: 8.2620364776490849}

# %%
print(min(scores_array, key=scores_array.get), "is the best pick for lambda")
# Out:
# 10 is the best pick for lambda

# %%
#5 (a)

# %% [markdown]
# We have the following norms for each weight we assign
#
# $w \in \{0.1, 0.5, 1 \}$
#
# and with
#
# $x \in [-1,1]$, we have
#
# $f(x) = w^Tx$
#
# and the kernel is given by
#
# $k(x,x') = x^T x'$
#
# Hence the following plot illustrates the above:

# %%
X_axis = np.linspace(-1,1,num=100)
weight = [0.1, 0.5, 1]

plt.plot(X_axis, weight[0]*X_axis, color= 'Blue')
Blue_patch = mpatches.Patch(color='Blue', label='weight = 0.1')
plt.plot(X_axis, weight[1]*X_axis, color= 'Orange')
Orange_patch = mpatches.Patch(color='Orange', label='weight = 0.5')
plt.plot(X_axis, weight[2]*X_axis, color= 'Green')
Green_patch = mpatches.Patch(color='Green', label='weight = 1')


plt.legend(handles=[Blue_patch, Orange_patch, Green_patch]) 
plt.show()

# %%
#5(b)
def Gaussian_kernel(x1, x2, p):
    out = []
    for i in x1:
        sub_out =[]
        for j in x2:
            q =  np.exp(-1/(2*(p**2)) * (i - j)**2) 
            sub_out.append(q)
        out.append(sub_out)
    return out

# %%
def feature_map(x, degree, p):
    out = []
    for i in range(degree):
        out.append((np.exp(-x**2 / (2*p**2)))*(x**(i)/ (p**i * (math.factorial(i)**(1/2)))))
    return out

# %%
def kernel_norm(phi):
    return np.dot(np.array(phi),np.array(phi).T)

# %%
def feature_map_matrix(X, p):
    out = []
    for x in X:
        out.append(feature_map(x, 150, p))
    return out

# %%
x_ax = np.linspace(-1, 1,num=50)
rng = np.random.RandomState(0)

# %%
for p in param:
    plt.plot(x_ax, kernel_norm(feature_map_matrix(x_ax, p)))
    plt.show()

# %% [markdown]
# We now calculate the norm of these functions

# %%
#5(c)
from sklearn import gaussian_process


X_GP = np.loadtxt("hw1-q5x.csv").reshape(-1,1)
Y_GP = np.loadtxt("hw1-q5y.csv").reshape(-1,1)

lam = [0.1 ,1 ,10]

# %%
kernel = gaussian_process.kernels.RBF(210)
GPR = gaussian_process.GaussianProcessRegressor(alpha = 0.03, kernel = kernel)

# %%
GPR.fit(X_GP,Y_GP)
Y_pred , Y_std = GPR.predict(X_ax.reshape(-1,1), return_std=True)
plt.scatter(X_GP,Y_GP)
plt.plot(X_ax, Y_pred, color="Green")
plt.fill_between(X_ax, (Y_pred.reshape(1,len(X_ax)) - Y_std)[0] ,(Y_pred.reshape(1,len(X_ax)) + Y_std)[0], alpha = 0.2)
plt.show()

# %% [markdown]
# We do the same thig using the first nine points instead

# %%
GPR.fit(X_GP[0:len(X_GP) - 1],Y_GP[0:len(X_GP) - 1])
Y_pred , Y_std = GPR.predict(X_ax.reshape(-1,1), return_std=True)
plt.scatter(X_GP,Y_GP)
plt.scatter(X_GP[len(X_GP) - 1],Y_GP[len(Y_GP) - 1],color = 'red')
plt.plot(X_ax, Y_pred, color="black")
plt.fill_between(X_ax, (Y_pred.reshape(1,len(X_ax)) - Y_std)[0] ,(Y_pred.reshape(1,len(X_ax)) + Y_std)[0], alpha = 0.2)
plt.show()

# %% [markdown]
# $\hat{f}(x) = k(x)^T(K+ \lambda I_m)^{-1}y = \phi(x)^T\Phi^T(\Phi\Phi^T + \lambda I_m)^{-1}y$

# %%
lam = [0.1 , 1, 10]

# %%
q = np.dot(np.array(Gaussian_kernel(X_ax,X_GP,10)[0]).T , np.linalg.inv(np.array(Gaussian_kernel(X_GP.reshape(-1,10)[0],X_GP.reshape(-1,10)[0],10)).reshape(10,10) + lam[0] * np.eye(len(X_GP))) * Y_GP)

# %%
for l in lam:
    part1 = np.array(Gaussian_kernel(X_GP,X_ax,0.1)).T[0]
    part2 = np.linalg.inv(np.array(Gaussian_kernel(X_GP.reshape(-1,10)[0],X_GP.reshape(-1,10)[0],0.1)).reshape(10,10) + (l * np.eye(len(X_GP))))
    part3 = np.dot(part1,part2)
    final = np.dot(part3,Y_GP)
    plt.plot(X_ax, final)
    plt.scatter(X_GP, Y_GP)
    plt.show()

# %%
for l in lam:
    part1 = np.array(Gaussian_kernel(X_GP[0:len(X_GP)-1],X_ax,0.1)).T[0]
    part2 = np.linalg.inv(np.array(Gaussian_kernel(X_GP[0:len(X_GP)-1].reshape(-1,9)[0],X_GP[0:len(X_GP)-1].reshape(-1,9)[0],0.1)).reshape(9,9) + (l * np.eye(9)))
    part3 = np.dot(part1,part2)
    final = np.dot(part3,Y_GP[0:9])
    plt.plot(X_ax, final)
    plt.scatter(X_GP, Y_GP)
    plt.show()
